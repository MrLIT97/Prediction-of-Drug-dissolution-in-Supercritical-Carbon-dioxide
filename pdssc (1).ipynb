# %% [markdown]
# # Machine Learning Modeling and Optimization of Drug Dissolution in Supercritical Carbon dioxide (SC-CO2)

# %%
import pandas as pd

drugs = pd.read_csv('C:\\Users\\USER\\Desktop\\FY Project\\Data sheets\\SCCO2 Drug Solubility Dataset1.csv')
drugs
# Out:
#               drug    temp  press  mw_drug  mp_drug  rho_scco2       sol  \
# 0     Rosuvastatin  308.00  121.6   236.00   435.00      771.0   0.19000
# 1     Rosuvastatin  308.00  152.0   236.00   435.00      818.0   0.24000
# 2     Rosuvastatin  308.00  182.4   236.00   435.00      850.0   0.33000
# 3     Rosuvastatin  308.00  212.8   236.00   435.00      876.0   0.39000
# 4     Rosuvastatin  308.00  243.2   236.00   435.00      897.0   0.43000
# ...            ...     ...    ...      ...      ...        ...       ...
# 2129  Erythromycin  313.15  299.9   733.93   488.65      909.7  13.21074
# 2130  Erythromycin  333.15  150.0   733.93   488.65      604.1  13.94467
# 2131  Erythromycin  333.25  200.0   733.93   488.65      723.3  20.55004
# 2132  Erythromycin  333.25  249.9   733.93   488.65      786.0  23.48576
# 2133  Erythromycin  333.35  300.0   733.93   488.65      829.0  27.88934
#
#       sol_mol_frac
# 0         0.000023
# 1         0.000027
# 2         0.000036
# 3         0.000041
# 4         0.000044
# ...            ...
# 2129      0.000890
# 2130      0.014000
# 2131      0.018000
# 2132      0.018000
# 2133      0.021000
#
# [2134 rows x 8 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
#drops columns not needed
drugs = drugs.drop(['drug', 'sol'], axis=1)
drugs
# Out:
#         temp  press  mw_drug  mp_drug  rho_scco2  sol_mol_frac
# 0     308.00  121.6   236.00   435.00      771.0      0.000023
# 1     308.00  152.0   236.00   435.00      818.0      0.000027
# 2     308.00  182.4   236.00   435.00      850.0      0.000036
# 3     308.00  212.8   236.00   435.00      876.0      0.000041
# 4     308.00  243.2   236.00   435.00      897.0      0.000044
# ...      ...    ...      ...      ...        ...           ...
# 2129  313.15  299.9   733.93   488.65      909.7      0.000890
# 2130  333.15  150.0   733.93   488.65      604.1      0.014000
# 2131  333.25  200.0   733.93   488.65      723.3      0.018000
# 2132  333.25  249.9   733.93   488.65      786.0      0.018000
# 2133  333.35  300.0   733.93   488.65      829.0      0.021000
#
# [2134 rows x 6 columns]

# %%
#checking data's dimenstion
drugs.shape
# Out:
# (2134, 6)

# %%
#Checking data types
drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2134 entries, 0 to 2133
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   temp          2134 non-null   float64
#  1   press         2134 non-null   float64
#  2   mw_drug       2134 non-null   float64
#  3   mp_drug       2134 non-null   float64
#  4   rho_scco2     2134 non-null   float64
#  5   sol_mol_frac  2134 non-null   float64
# dtypes: float64(6)
# memory usage: 100.2 KB

# %%
#checking statistical properties
drugs.describe().T
# Out:
#                count        mean         std         min         25%  \
# temp          2134.0  327.249063   14.279248  303.000000  318.000000
# press         2134.0  239.008997   79.280146   80.000000  182.000000
# mw_drug       2134.0  323.283704  141.700122   96.000000  237.000000
# mp_drug       2134.0  406.094470  105.280469  115.000000  369.150000
# rho_scco2     2134.0  743.578457  185.267102    3.458823  693.575000
# sol_mol_frac  2134.0    0.000371    0.001135    0.000000    0.000011
#
#                      50%        75%      max
# temp          328.000000  338.00000  373.150
# press         243.000000  304.00000  500.000
# mw_drug       289.380000  384.64000  853.906
# mp_drug       431.150000  480.00000  608.150
# rho_scco2     792.000000  858.00000  992.000
# sol_mol_frac    0.000054    0.00023    0.021

# %%
#Overview of variable distributtions
import matplotlib.pyplot as plt

axes = drugs.hist(figsize=(10,10), bins=16)
for ax in axes.flatten():
    ax.grid(False)
plt.show()

# %%
#Closer view at target variable distribution
import seaborn as sns

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(drugs['sol_mol_frac'])

plt.subplot(122)
sns.kdeplot(drugs['sol_mol_frac'])
plt.show()

# %%
#Overview of general dataset correlations
plt.figure(figsize=(12,5))
sns.pairplot(drugs)
plt.show()

# %%
#Overview of Target-Features correlation
import seaborn as sns
plt.figure(figsize=(12,5))
sns.pairplot(drugs, y_vars=['sol_mol_frac'], x_vars=['temp', 'press', 'mw_drug', 'mp_drug', 'rho_scco2'])
plt.show()

# %% [markdown]
# ## Statistical Test Analysis with No Target-Feature Correlation Null Hypothesis

# %%
#Overall Pearson Correlation
drugs.corr()
# Out:
#                   temp     press   mw_drug   mp_drug  rho_scco2  sol_mol_frac
# temp          1.000000  0.034274 -0.004556 -0.066843  -0.366756      0.095379
# press         0.034274  1.000000 -0.050634 -0.063696   0.497761      0.165942
# mw_drug      -0.004556 -0.050634  1.000000  0.216240   0.012571      0.010982
# mp_drug      -0.066843 -0.063696  0.216240  1.000000  -0.014709     -0.155761
# rho_scco2    -0.366756  0.497761  0.012571 -0.014709   1.000000      0.082220
# sol_mol_frac  0.095379  0.165942  0.010982 -0.155761   0.082220      1.000000

# %%
#Overall Spearman Correlation
drugs.corr(method='spearman')
# Out:
#                   temp     press   mw_drug   mp_drug  rho_scco2  sol_mol_frac
# temp          1.000000  0.037646  0.030619 -0.065548  -0.566185      0.133392
# press         0.037646  1.000000 -0.051901 -0.085455   0.665476      0.373509
# mw_drug       0.030619 -0.051901  1.000000  0.223809  -0.042455     -0.148942
# mp_drug      -0.065548 -0.085455  0.223809  1.000000  -0.003074     -0.427108
# rho_scco2    -0.566185  0.665476 -0.042455 -0.003074   1.000000      0.154075
# sol_mol_frac  0.133392  0.373509 -0.148942 -0.427108   0.154075      1.000000

# %%
#Visualizing Spearman Correlation Coefficients
import seaborn as sns

plt.figure(figsize=(7,4))
sns.heatmap(drugs.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# ### Coefficient Correlation of Features to Target Variable

# %%
from scipy.stats import pearsonr,spearmanr,kendalltau

#Pearson Correlation Coefficients
MW_Solu_pear = pearsonr(drugs['mw_drug'], drugs['sol_mol_frac'])[0]
MP_Solu_pear = pearsonr(drugs['mp_drug'], drugs['sol_mol_frac'])[0]
Density_pear = pearsonr(drugs['rho_scco2'], drugs['sol_mol_frac'])[0]
Pressure_pear =  pearsonr(drugs['press'], drugs['sol_mol_frac'])[0]
Temp_pear =  pearsonr(drugs['temp'], drugs['sol_mol_frac'])[0]

#Spearman Correlation Coefficients
MW_Solu_sper = spearmanr(drugs['mw_drug'], drugs['sol_mol_frac'])[0]
MP_Solu_sper = spearmanr(drugs['mp_drug'], drugs['sol_mol_frac'])[0]
Density_sper = spearmanr(drugs['rho_scco2'], drugs['sol_mol_frac'])[0]
Pressure_sper =  spearmanr(drugs['press'], drugs['sol_mol_frac'])[0]
Temp_sper = spearmanr(drugs['temp'], drugs['sol_mol_frac'])[0]

#Kendall Correlation Coefficients
MW_Solu_kend = kendalltau(drugs['mw_drug'], drugs['sol_mol_frac'])[0]
MP_Solu_kend = kendalltau(drugs['mp_drug'], drugs['sol_mol_frac'])[0]
Density_kend = kendalltau(drugs['rho_scco2'], drugs['sol_mol_frac'])[0]
Pressure_kend =  kendalltau(drugs['press'], drugs['sol_mol_frac'])[0]
Temp_kend = kendalltau(drugs['temp'], drugs['sol_mol_frac'])[0]

#Pearson Correlation P_values
MW_Solu_ppv = pearsonr(drugs['mw_drug'], drugs['sol_mol_frac'])[1]
MP_Solu_ppv = pearsonr(drugs['mp_drug'], drugs['sol_mol_frac'])[1]
Density_ppv = pearsonr(drugs['rho_scco2'], drugs['sol_mol_frac'])[1]
Pressure_ppv =  pearsonr(drugs['press'], drugs['sol_mol_frac'])[1]
Temp_ppv =  pearsonr(drugs['temp'], drugs['sol_mol_frac'])[1]

#Spearman Correlation P_values
MW_Solu_spv = spearmanr(drugs['mw_drug'], drugs['sol_mol_frac'])[1]
MP_Solu_spv = spearmanr(drugs['mp_drug'], drugs['sol_mol_frac'])[1]
Density_spv = spearmanr(drugs['rho_scco2'], drugs['sol_mol_frac'])[1]
Pressure_spv =  spearmanr(drugs['press'], drugs['sol_mol_frac'])[1]
Temp_spv = spearmanr(drugs['temp'], drugs['sol_mol_frac'])[1]

#Kendall Correlation P_values
MW_Solu_kpv = kendalltau(drugs['mw_drug'], drugs['sol_mol_frac'])[1]
MP_Solu_kpv = kendalltau(drugs['mp_drug'], drugs['sol_mol_frac'])[1]
Density_kpv = kendalltau(drugs['rho_scco2'], drugs['sol_mol_frac'])[1]
Pressure_kpv =  kendalltau(drugs['press'], drugs['sol_mol_frac'])[1]
Temp_kpv = kendalltau(drugs['temp'], drugs['sol_mol_frac'])[1]

#Create a Dataframe for the Correlation Coefficients
df = [["Molar Weight", MW_Solu_pear, MW_Solu_sper, MW_Solu_kend],
      ["Melting Point", MP_Solu_pear, MP_Solu_sper, MP_Solu_kend],
      ["SCCO2_Density",Density_pear,Density_sper, Density_kend],
      ["Pressure", Pressure_pear,Pressure_sper, Pressure_kend],
     ["Temperature",Temp_pear,Temp_sper, Temp_kend]]
df = pd.DataFrame(df, columns=["Params", "Pearson", "Spearman", "Kendall"])

#Create a Dataframe for the Correlation P_values
df2 = [["Molar Weight", MW_Solu_ppv, MW_Solu_spv, MW_Solu_kpv],
      ["Melting Point", MP_Solu_ppv, MP_Solu_spv, MP_Solu_kpv],
       ["SCCO2_Density",Density_ppv,Density_spv, Density_kpv],
      ["Pressure", Pressure_ppv,Pressure_spv, Pressure_kpv],
     ["Temperature",Temp_ppv,Temp_spv, Temp_kpv]]
df2 = pd.DataFrame(df2, columns=[" ", "Pearson", "Spearman", "Kendall"])
print("Correlation P_values")
print(df2)

#Visualise Corr_Coeffs
df.plot(x="Params",y=["Pearson","Spearman", "Kendall"], kind="bar", figsize=(8,6))
plt.title('Correlation Analysis')
plt.ylabel("Correlation Coeffient")
plt.xticks(rotation=360)
plt.show()
# Out:
# Correlation P_values
#                        Pearson      Spearman       Kendall
# 0   Molar Weight  6.121395e-01  4.678810e-12  3.264290e-12
# 1  Melting Point  4.640707e-13  2.304572e-95  1.205190e-89
# 2  SCCO2_Density  1.433136e-04  8.299040e-13  6.309179e-13
# 3       Pressure  1.212079e-14  1.269197e-71  1.260231e-71
# 4    Temperature  1.017035e-05  6.165613e-10  1.015211e-09

# %% [markdown]
# # Machine Learning Modeling

# %% [markdown]
# **Importing necessary libraries**

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse

# %% [markdown]
# **Data Preprocessing**

# %%
X = drugs.drop('sol_mol_frac', axis=1).values
y = drugs['sol_mol_frac'].values
#transforming target variable
tr = QuantileTransformer(output_distribution='normal')
y_tr = tr.fit_transform(y.reshape(-1,1)).ravel()
#splitting dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_tr, test_size=0.25, random_state=42)
#Scaling features
scaler = RobustScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
#checking normalized target variable
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.hist(y_tr)

#density curve
plt.subplot(122)
sns.kdeplot(y_tr)
plt.show()

# %%
#checking scaled features
scaled_train_x = pd.DataFrame(X_train_sc, columns=drugs.drop('sol_mol_frac', axis=1).columns)
scaled_test_x = pd.DataFrame(X_test_sc, columns=drugs.drop('sol_mol_frac', axis=1).columns)
scaled_x = pd.concat([scaled_train_x, scaled_test_x], axis=0, ignore_index=True)
scaled_x
# Out:
#       temp     press   mw_drug   mp_drug  rho_scco2
# 0     1.00 -0.247541 -0.361555  0.034732  -0.890883
# 1     1.00  0.745902 -0.359794 -2.040144   0.025454
# 2     1.00  0.745902 -1.309808 -0.559314   0.025454
# 3     1.00  0.909836  0.473923 -0.383401   0.120906
# 4    -0.50  0.745902 -0.027635 -1.315652   0.750887
# ...    ...       ...       ...       ...        ...
# 2129 -0.75  1.286885 -0.916147  0.396933   1.049969
# 2130  0.50  0.500000 -0.287050  0.147497   0.127269
# 2131  0.00 -0.745902 -0.841777 -0.595399  -0.859066
# 2132 -0.50  0.254098  0.000000 -2.852052   0.528166
# 2133 -0.75  0.467213  1.676328  0.197113   0.754069
#
# [2134 rows x 5 columns]

# %%
scaled_x.hist(figsize=(6,8))
plt.show()

# %% [markdown]
# ### 1. TRAINING SUPPORT VECTOR REGRESSOR (SVR)

# %%
#Fitting default model
svr = SVR()
svr.fit(X_train_sc, y_train)
svr.predict(X_test_sc)
print("R_squared for training set:", round(svr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, svr.predict(X_train_sc)), 3))
print("R_squared for test set:", round(svr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, svr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 0.417
# MSE for training set: 0.767
# R_squared for test set: 0.423
# MSE for test set: 0.713

# %%
#GridSearch for Optimization
from sklearn.model_selection import GridSearchCV, KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)
param_grid = {'C': np.arange(2,20,2),
              'gamma': ['auto',0.01,0.1,1],
              'epsilon': [0.01,0.1,1]}
svr = SVR()
grid_search = GridSearchCV(svr, param_grid, cv=kf, scoring = 'r2', verbose=1, n_jobs=-1, error_score='raise')
grid_search.fit(X_train_sc, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best param_score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best parameters: {'C': 16, 'epsilon': 0.1, 'gamma': 1}
# Best param_score: 0.63225623552931

# %%
#Visualized Error minimization tracking
from sklearn.metrics import mean_squared_error as mse
C = 50
train_score = []
test_score = []
for i in range(1,C+1):
    svr = SVR(C=i, epsilon= 0.1, gamma= 1)
    svr.fit(X_train_sc, y_train)
    svr.predict(X_test_sc)
    test_score.append(mse(y_test, svr.predict(X_test_sc)))
    train_score.append(mse(y_train, svr.predict(X_train_sc)))
plt.plot(np.arange(C), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(C), test_score, "r-", label= "Test Set Error")
plt.xlabel("Regularization Iterations")
plt.ylabel("MeanSquaredError")
plt.title("Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#fitting tuned model
svr = SVR(C = 18, epsilon= 0.1, gamma= 1)
svr.fit(X_train_sc, y_train)
svr.predict(X_test_sc)
print("R_squared for training set:", round(svr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, svr.predict(X_train_sc)), 3))
print("R_squared for test set:", round(svr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, svr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 0.837
# MSE for training set: 0.215
# R_squared for test set: 0.69
# MSE for test set: 0.383

# %%
#Evaluating Performance with Cross-Validation
from sklearn.model_selection import cross_val_score
svr_cv = -cross_val_score(svr, X_train_sc, y_train, cv=10, scoring = "neg_mean_squared_error")
svr_mse = round(np.mean(svr_cv),3)
svr_std = round(np.std(svr_cv), 3)
print("Cross Validation MSE:", svr_mse)
print("Cross Validation Std:", svr_std)
# Out:
# Cross Validation MSE: 0.427
# Cross Validation Std: 0.161

# %% [markdown]
# **SVR Performance Diplay**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Plotting Actual Values against Predicted Values
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.scatter(x = y_test, y= svr.predict(X_test_sc), alpha = 0.6, label='test set predictions')
plt.scatter(x = y_train, y= svr.predict(X_train_sc), alpha = 0.5, label='train set predictions')
plt.plot(y_test, y_test, label='best fit')
plt.legend()
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('SVR Performance R_squared=' + str(round(svr.score(X_test_sc, y_test),3)))

#Plotting the Optimization Performance
from sklearn.metrics import mean_squared_error as mse
C = 50
train_score = []
test_score = []
for i in range(1,C+1):
    svr = SVR(C=i, epsilon= 0.1, gamma= 1)
    svr.fit(X_train_sc, y_train)
    svr.predict(X_test_sc)
    test_score.append(mse(y_test, svr.predict(X_test_sc)))
    train_score.append(mse(y_train, svr.predict(X_train_sc)))
plt.subplot(122)
plt.plot(np.arange(C), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(C), test_score, "r-", label= "Test Set Error")
plt.xlabel("Regularization Iterations")
plt.ylabel("MeanSquaredError")
plt.title("SVR Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#Display of Actual and Predicted Values distributions
plt.figure(figsize=(10,7))
sns.histplot(y_test, label="Actual Values")
sns.histplot(svr.predict(X_test_sc), alpha=0.6, label="Predicted Values")
plt.legend()
plt.ylabel("count")
plt.xlabel("values")
plt.title("SVR Distribution Plot - Actual Values Vs Predicted Values")
plt.show()

# %% [markdown]
# ### 2. TRAINING RANDOM FOREST REGRESSOR (RFR)

# %%
#Fitting default model
rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train_sc, y_train)
rfr.predict(X_test_sc)
print("R_squared for training set:", round(rfr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, rfr.predict(X_train_sc)),3))
print("R_squared for test set:", round(rfr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, rfr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 0.986
# MSE for training set: 0.019
# R_squared for test set: 0.961
# MSE for test set: 0.049

# %%
#GridSearch for Optimization
kf = KFold(n_splits=5, shuffle=True, random_state=42)
param_grid = {'n_estimators': np.arange(4,32,4),
              'max_depth': [None, 10, 20, 30],
              'min_samples_split': [2,5,10],
              'min_samples_leaf': [1,2,4]}
rfr = RandomForestRegressor()
grid_search = GridSearchCV(rfr, param_grid, cv=kf, scoring = 'r2')
grid_search.fit(X_train_sc, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best param_score:", grid_search.best_score_)
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16}
# Best param_score: 0.8821715002697637

# %%
#Visualized Error minimization Tracking
n_estimators= 100
train_score = []
test_score = []
for i in range(1,n_estimators+1):
    rfr = RandomForestRegressor(n_estimators=i, max_depth=None, 
                                min_samples_split=2, min_samples_leaf=1,
                                random_state=42)
    rfr.fit(X_train_sc, y_train)
    rfr.predict(X_test_sc)
    test_score.append(mse(y_test, rfr.predict(X_test_sc)))
    train_score.append(mse(y_train, rfr.predict(X_train_sc)))
plt.plot(np.arange(n_estimators), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(n_estimators), test_score, "r-", label= "Test Set Errot")
plt.xlabel("Forest Iterations")
plt.ylabel("MeanSquaredError")
plt.title("Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#fit model with tuned Hyperparameters
rfr = RandomForestRegressor(n_estimators=12, max_depth=None, 
                                min_samples_split=2, min_samples_leaf=1,
                                random_state=42)
rfr.fit(X_train_sc, y_train)
rfr.predict(X_test_sc)
print("R_squared for training set:", round(rfr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, rfr.predict(X_train_sc)),3))
print("R_squared for test set:", round(rfr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, rfr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 0.985
# MSE for training set: 0.019
# R_squared for test set: 0.972
# MSE for test set: 0.035

# %%
#Evaluating Performance with Cross Validation
rfr_cv = -cross_val_score(rfr, X_train_sc, y_train, cv=10, scoring = "neg_mean_squared_error")
rfr_mse = round(np.mean(rfr_cv),3)
rfr_std = round(np.std(rfr_cv), 3)
print("Cross Validation MSE:", rfr_mse)
print("Cross Validation Std:", rfr_std)
# Out:
# Cross Validation MSE: 0.14
# Cross Validation Std: 0.095

# %% [markdown]
# **RFR Performance Display**

# %%
#Plotting Actual Values against Predicted Values
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.scatter(x = y_test, y= rfr.predict(X_test_sc), alpha = 0.6, label='test set predictions')
plt.scatter(x = y_train, y= rfr.predict(X_train_sc), alpha = 0.6, label='train set predictions')
plt.plot(y_test, y_test, label='best fit')
plt.legend()
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('RFR Performance R_squared=' + str(round(rfr.score(X_test_sc, y_test),3)))

#Ploting Optimization Performance
n_estimators= 100
train_score = []
test_score = []
for i in range(1,n_estimators+1):
    rfr = RandomForestRegressor(n_estimators=i, random_state=42)
    rfr.fit(X_train_sc, y_train)
    rfr.predict(X_test_sc)
    test_score.append(mse(y_test, rfr.predict(X_test_sc)))
    train_score.append(mse(y_train, rfr.predict(X_train_sc)))
plt.subplot(1,2,2)
plt.plot(np.arange(n_estimators), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(n_estimators), test_score, "r-", label= "Test Set Error")
plt.xlabel("Forest Iterations")
plt.ylabel("MeanSquaredError")
plt.title("RFR Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#Display of Actual and Predicted Values distributions
plt.figure(figsize=(10,7))
sns.histplot(y_test, label="Actual Values")
sns.histplot(rfr.predict(X_test_sc), alpha=0.6, label="Predicted Values")
plt.legend()
plt.ylabel("count")
plt.xlabel("values")
plt.title("RFR Distribution Plot - Actual Values Vs Predicted Values")
plt.show()

# %% [markdown]
# ### 3. TRAINING GRADIENT BOOSTING REGRESSOR (GBR)

# %%
#Fitting model with default Hyperparameters
gbr = GradientBoostingRegressor(random_state=42)
gbr.fit(X_train_sc, y_train)
gbr.predict(X_test_sc)
print(gbr.score(X_train_sc, y_train))
print(gbr.score(X_test_sc, y_test))
# Out:
# 0.892324205164645
# 0.8850732488870885

# %%
#GridSearch for Optimization
kf = KFold(n_splits=5, shuffle=True, random_state=42)
param_grid = {'n_estimators': np.arange(100,500,100),
              'learning_rate': [0.01, 0.1, 0.2],
              'max_depth': [3, 5, 7, 9],
              'subsample': [0.7, 0.8, 1.0],
              'min_samples_split': [2,5,10],
              'min_samples_leaf': [1,2,4]}
gbr=GradientBoostingRegressor()
grid_search = GridSearchCV(gbr, param_grid, cv=kf, scoring = 'r2')
grid_search.fit(X_train_sc, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best param_score:", grid_search.best_score_)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400, 'subsample': 1.0}
# Best param_score: 0.9098355025738076

# %%
#Visualized Error minimization Tracking
best_params = {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1,
          'min_samples_split': 5, 'n_estimators': 400, 'subsample': 1.0}
gbr = GradientBoostingRegressor(**best_params)
gbr.fit(X_train_sc, y_train)
gbr.predict(X_test_sc)
test_score = np.zeros((best_params["n_estimators"],), dtype=np.float64)
for i, y_pred1 in enumerate(gbr.staged_predict(X_test_sc)):
    test_score[i] = mse(y_test, y_pred1)
plt.plot(np.arange(best_params["n_estimators"])+1, gbr.train_score_, "b-", label="Training Set Error")
plt.plot(np.arange(best_params["n_estimators"])+1, test_score, "r-", label= "Test Set Error")
plt.xlabel("Boosting Iterations")
plt.ylabel("MeanSquaredError")
plt.title("GBR Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#Fitting tuned model
best_params = {'learning_rate' : 0.1, 'max_depth' : 9, 'min_samples_leaf' :1, 
                                'min_samples_split' : 7, 'n_estimators' : 450, 'subsample' :1.0}
gbr = GradientBoostingRegressor(**best_params, random_state=42)
gbr.fit(X_train_sc, y_train)
gbr.predict(X_test_sc)
print("R_squared for training set:", round(gbr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, gbr.predict(X_train_sc)),3))
print("R_squared for test set:", round(gbr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, gbr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 1.0
# MSE for training set: 0.0
# R_squared for test set: 0.971
# MSE for test set: 0.036

# %%
#Evaluating Performance with Cross Validation
gbr_cv = -cross_val_score(gbr, X_train_sc, y_train, cv=10, scoring = "neg_mean_squared_error")
gbr_mse = round(np.mean(gbr_cv),3)
gbr_std = round(np.std(gbr_cv), 3)
print("Cross Validation MSE:", gbr_mse)
print("Cross Validation Std:", gbr_std)
# Out:
# Cross Validation MSE: 0.121
# Cross Validation Std: 0.097

# %% [markdown]
# **GBR Performance Display**

# %%
#Plotting Actual Values against Predicted Values
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.scatter(x = y_test, y= gbr.predict(X_test_sc), alpha = 0.6, label='test set predictions')
plt.scatter(x = y_train, y= gbr.predict(X_train_sc), alpha = 0.6, label='train set predictions')
plt.plot(y_test, y_test, label='best fit')
plt.legend()
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('GBR Performance R_squared=' + str(round(gbr.score(X_test_sc, y_test),3)))


#Plotting Optimization Performance
test_score = np.zeros((best_params["n_estimators"],), dtype=np.float64)
for i, y_pred1 in enumerate(gbr.staged_predict(X_test_sc)):
    test_score[i] = mse(y_test, y_pred1)
plt.subplot(122)
plt.title("GBR Error Minimization Tracking")
plt.plot(np.arange(best_params["n_estimators"])+1, gbr.train_score_, "b-", label="Training Set Error")
plt.plot(np.arange(best_params["n_estimators"])+1, test_score, "r-", label= "Test Set Error")
plt.xlabel("Boosting Iterations")
plt.ylabel("MeanSquaredError")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#Display of Actual and Predicted Values distributions
plt.figure(figsize=(10,7))
sns.histplot(y_test, label="Actual Values")
sns.histplot(gbr.predict(X_test_sc), alpha=0.6, label="Predicted Values")
plt.legend()
plt.ylabel("count")
plt.xlabel("values")
plt.title("GBR Distribution Plot - Actual Values Vs Predicted Values")
plt.show()

# %% [markdown]
# ### 4. TRAINING DECISION TREE REGRESSOR (DTR)

# %%
#Fitting default model
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=42)
dtr.fit(X_train_sc, y_train)
dtr.predict(X_test_sc)
print("R_squared for training set:", round(dtr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, dtr.predict(X_train_sc)),3))
print("R_squared for test set:", round(dtr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, dtr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 1.0
# MSE for training set: 0.0
# R_squared for test set: 0.924
# MSE for test set: 0.094

# %%
#GridSearch for Optimization
kf = KFold(n_splits=5, shuffle=True, random_state=42)
param_grid = {'max_depth': np.arange(1,20,3),
              'min_samples_split': [1,2,5,10],
              'min_samples_leaf': [1,2,4],
             'max_features':[None,'auto','sqrt','log2']}
dtr=DecisionTreeRegressor()
grid_search = GridSearchCV(dtr, param_grid, cv=kf, scoring = 'r2', verbose=1, n_jobs=-1, error_score='raise')
grid_search.fit(X_train_sc, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best param_score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 336 candidates, totalling 1680 fits
# Best parameters: {'max_depth': 16, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1}
# Best param_score: 0.8652483134686934

# %%
#Visualized Error minimization Tracking
max_depth= 40
train_score = []
test_score = []
for i in range(1,max_depth+1):
    param_grid = {'max_depth': i, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
    dtr = DecisionTreeRegressor(**param_grid, random_state=42)
    dtr.fit(X_train_sc, y_train)
    dtr.predict(X_test_sc)
    test_score.append(mse(y_test, dtr.predict(X_test_sc)))
    train_score.append(mse(y_train, dtr.predict(X_train_sc)))
plt.plot(np.arange(max_depth), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(max_depth), test_score, "r-", label= "Test Set Errot")
plt.xlabel("Depth Iterations")
plt.ylabel("MeanSquaredError")
plt.title("DTR Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#Fitting tuned model
param_grid = {'max_depth': 11, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
dtr = DecisionTreeRegressor(**param_grid, random_state=42)
dtr.fit(X_train_sc, y_train)
dtr.predict(X_test_sc)
print("R_squared for training set:", round(dtr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, dtr.predict(X_train_sc)),3))
print("R_squared for test set:", round(dtr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, dtr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 0.97
# MSE for training set: 0.039
# R_squared for test set: 0.916
# MSE for test set: 0.103

# %%
#Evaluating Performance with Cross Validation
dtr_cv = -cross_val_score(dtr, X_train_sc, y_train, cv=5, scoring = "neg_mean_squared_error")
dtr_mse = round(np.mean(dtr_cv),3)
dtr_std = round(np.std(dtr_cv), 3)
print("Cross Validation MSE:", dtr_mse)
print("Cross Validation Std:", dtr_std)
# Out:
# Cross Validation MSE: 0.187
# Cross Validation Std: 0.055

# %% [markdown]
# **DTR Performance Display**

# %%
#Plotting Actual Values against Predicted Values
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.scatter(x = y_test, y= dtr.predict(X_test_sc), alpha = 0.6, label='test set predictions')
plt.scatter(x = y_train, y= dtr.predict(X_train_sc), alpha = 0.6, label='train set predictions')
plt.plot(y_test, y_test, label='best fit')
plt.legend()
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('DTR Performance R_squared=' + str(round(dtr.score(X_test_sc, y_test),3)))

#Plotting Optimization Performance
max_depth= 40
train_score = []
test_score = []
for i in range(1,max_depth+1):
    param_grid = {'max_depth': i, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2}
    dtr = DecisionTreeRegressor(**param_grid, random_state=42)
    dtr.fit(X_train_sc, y_train)
    dtr.predict(X_test_sc)
    test_score.append(mse(y_test, dtr.predict(X_test_sc)))
    train_score.append(mse(y_train, dtr.predict(X_train_sc)))
plt.subplot(1,2,2)
plt.plot(np.arange(max_depth), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(max_depth), test_score, "r-", label= "Test Set Errot")
plt.xlabel("Depth Iterations")
plt.ylabel("MeanSquaredError")
plt.title("DTR Error Minimization Tracking")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
#Display of Actual and Predicted Values distributions
plt.figure(figsize=(10,7))
sns.histplot(y_test, label="Actual Values")
sns.histplot(dtr.predict(X_test_sc), alpha=0.6, label="Predicted Values")
plt.legend()
plt.ylabel("count")
plt.xlabel("values")
plt.title("DTR Distribution Plot - Actual Values Vs Predicted Values")
plt.show()

# %% [markdown]
# ### 5. TRAINING K-NEAREST NEIGHBOR REGRESSOR (KNNR)

# %%
#Fitting default model
knnr = KNeighborsRegressor()
knnr.fit(X_train_sc, y_train)
knnr.predict(X_test_sc)
print("R_squared for training set:", round(knnr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, knnr.predict(X_train_sc)),3))
print("R_squared for test set:", round(knnr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, knnr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 0.683
# MSE for training set: 0.417
# R_squared for test set: 0.543
# MSE for test set: 0.565

# %%
#GridSearch for Optimization
kf = KFold(n_splits=5, shuffle=True, random_state=42)
param_grid = {'n_neighbors': [3,5,7,9,11,13],
              'weights': ['uniform', 'distance'],
              'p': [1,2]}
knn = KNeighborsRegressor()
grid_search = GridSearchCV(knn, param_grid, cv=kf, scoring = 'r2', verbose=1, n_jobs=-1)
grid_search.fit(X_train_sc, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best param_score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# Best param_score: 0.6180418135288418

# %%
#Visualized Error minimization Tracking
n_neighbors = 25
train_score = []
test_score = []
for i in range(1,n_neighbors+1):
    knnr = KNeighborsRegressor(n_neighbors=i, p=1, weights='distance')
    knnr.fit(X_train_sc, y_train)
    knnr.predict(X_test_sc)
    train_score.append(mse(y_train, knnr.predict(X_train_sc)))
    test_score.append(mse(y_test, knnr.predict(X_test_sc)))
plt.plot(np.arange(n_neighbors), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(n_neighbors), test_score, "r-", label="Test Set Error")
plt.title("KNNR Error Minimization Tracking")
plt.xlabel("Neighbors iteration")
plt.ylabel("MeanSquaredError")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Fitting tuned model
knnr = KNeighborsRegressor(n_neighbors=3, p=1, weights='distance')
knnr.fit(X_train_sc, y_train)
knnr.predict(X_test_sc)
print("R_squared for training set:", round(knnr.score(X_train_sc, y_train),3))#Performance on Training set
print("MSE for training set:", round(mse(y_train, knnr.predict(X_train_sc)),3))
print("R_squared for test set:", round(knnr.score(X_test_sc, y_test),3)) #Performance on Test set
print("MSE for test set:", round(mse(y_test, knnr.predict(X_test_sc)),3))
# Out:
# R_squared for training set: 1.0
# MSE for training set: 0.0
# R_squared for test set: 0.739
# MSE for test set: 0.323

# %%
#Evaluating Performance with Cross Validation
knnr_cv = -cross_val_score(knnr, X_train_sc, y_train, cv=5, scoring = "neg_mean_squared_error")
knnr_mse = round(np.mean(knnr_cv),3)
knnr_std = round(np.std(knnr_cv), 3)
print("Cross Validation MSE:", knnr_mse)
print("Cross Validation Std:", knnr_std)
# Out:
# Cross Validation MSE: 0.479
# Cross Validation Std: 0.127

# %% [markdown]
# **KNNR Performance Display**

# %%
#Plotting Actual Values against Predicted Values
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.scatter(x = y_test, y= knnr.predict(X_test_sc), alpha = 0.6, label='test set predictions')
plt.scatter(x = y_train, y= knnr.predict(X_train_sc), alpha = 0.6, label='train set predictions')
plt.plot(y_test, y_test, label='best fit')
plt.legend()
plt.tight_layout()
plt.legend()
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('KNNR Performance R_squared=' + str(round(knnr.score(X_test_sc, y_test),3)))

#Plotting Optimization Performance
n_neighbors = 25
train_score = []
test_score = []
for i in range(1,n_neighbors+1):
    knnr = KNeighborsRegressor(n_neighbors=i, p=1, weights='distance')
    knnr.fit(X_train_sc, y_train)
    knnr.predict(X_test_sc)
    train_score.append(mse(y_train, knnr.predict(X_train_sc)))
    test_score.append(mse(y_test, knnr.predict(X_test_sc)))
plt.subplot(122)
plt.plot(np.arange(n_neighbors), train_score, "b-", label="Training Set Error")
plt.plot(np.arange(n_neighbors), test_score, "r-", label="Test Set Error")
plt.title("KNNR Error Minimization Tracking")
plt.xlabel("Neighbors iteration")
plt.ylabel("MeanSquaredError")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Display of Actual and Predicted Values distributions
plt.figure(figsize=(10,7))
sns.histplot(y_test, label="Actual Values")
sns.histplot(knnr.predict(X_test_sc), alpha=0.6, label="Predicted Values")
plt.legend()
plt.ylabel("count")
plt.xlabel("values")
plt.title("KNNR Distribution Plot - Actual Values Vs Predicted Values")
plt.show()

# %% [markdown]
# ## Cross Validation Evaluation of Models

# %%
#Cross validation Error and Deviation
cv = {'model': ['Decision Tree Regressor (DTR)', 'RandomForest Regressor (RFR)', 'Gradient Boosting Regressor (GBR)', 
                         'Support Vector Regressor (SVR)', 'K-Nearest Neighbor Regressor (KNNR)'],
               'CV MSE': [dtr_mse, rfr_mse, gbr_mse, svr_mse, knnr_mse],
              'CV Std': [dtr_std, rfr_std, gbr_std, svr_std, knnr_std]}
cv = pd.DataFrame(cv)
cv
# Out:
#                                  model  CV MSE  CV Std
# 0        Decision Tree Regressor (DTR)   0.187   0.055
# 1         RandomForest Regressor (RFR)   0.140   0.095
# 2    Gradient Boosting Regressor (GBR)   0.121   0.097
# 3       Support Vector Regressor (SVR)   0.427   0.161
# 4  K-Nearest Neighbor Regressor (KNNR)   0.479   0.127

# %%
#Abbreviating model names
cv['model'] = ['DTR', 'RFR', 'GBR', 'SVR', 'KNNR']
cv
# Out:
#   model  CV MSE  CV Std
# 0   DTR   0.187   0.055
# 1   RFR   0.140   0.095
# 2   GBR   0.121   0.097
# 3   SVR   0.427   0.161
# 4  KNNR   0.479   0.127

# %%
plt.bar(cv['model'],cv['CV MSE'], label='MSE')
plt.bar(cv['model'],cv['CV Std'], label='Std')
plt.xticks(rotation=90)
plt.ylabel('CV MSE/Std')
plt.title('Cross Validation Evaluation')
plt.xlabel('model')
plt.legend()
plt.show()

# %% [markdown]
# ## Commentary

# %% [markdown]
# **Overall modelling outcome:**
# * The ensemble regressors (i.e regressors built on tree architecture) which are Decision Tree Regressor, the Random Forest Regressor and the Gradient Boosting Regressor perform the best by greatly avoiding overfitting despite the limited data available.
#
# * However, Support Vector Regressor and the K-Nearest Neighbor Regressor perform quite woefully with high proneness to overfitting.
#
# **Conclusive Insight:** Specifically, the ensemble models are highly robust and effective for predictive optimization for the essence of achieving data-driven drug dissolution in pharmaceutical production of drugs over a diversified range of therapeutic classes.

# %%
#An quickview of predicted values to actual values
y_pred_org = tr.inverse_transform(gbr.predict(X_test_sc).reshape(-1,1))
y_test_org = tr.inverse_transform(y_test.reshape(-1,1))
A = pd.DataFrame({'Actual': y_test_org.flatten(), 'Predicted': y_pred_org.flatten(), 'Error': (y_test_org - y_pred_org).flatten()})
A.head(10).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_fbcec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbcec_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_fbcec_level0_col1" class="col_heading level0 col1" >Predicted</th>
#       <th id="T_fbcec_level0_col2" class="col_heading level0 col2" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbcec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbcec_row0_col0" class="data row0 col0" >0.000148</td>
#       <td id="T_fbcec_row0_col1" class="data row0 col1" >0.000124</td>
#       <td id="T_fbcec_row0_col2" class="data row0 col2" >0.000024</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbcec_row1_col0" class="data row1 col0" >0.000017</td>
#       <td id="T_fbcec_row1_col1" class="data row1 col1" >0.000014</td>
#       <td id="T_fbcec_row1_col2" class="data row1 col2" >0.000003</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbcec_row2_col0" class="data row2 col0" >0.000049</td>
#       <td id="T_fbcec_row2_col1" class="data row2 col1" >0.000046</td>
#       <td id="T_fbcec_row2_col2" class="data row2 col2" >0.000003</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbcec_row3_col0" class="data row3 col0" >0.000017</td>
#       <td id="T_fbcec_row3_col1" class="data row3 col1" >0.000018</td>
#       <td id="T_fbcec_row3_col2" class="data row3 col2" >-0.000002</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fbcec_row4_col0" class="data row4 col0" >0.000466</td>
#       <td id="T_fbcec_row4_col1" class="data row4 col1" >0.000489</td>
#       <td id="T_fbcec_row4_col2" class="data row4 col2" >-0.000023</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fbcec_row5_col0" class="data row5 col0" >0.000013</td>
#       <td id="T_fbcec_row5_col1" class="data row5 col1" >0.000016</td>
#       <td id="T_fbcec_row5_col2" class="data row5 col2" >-0.000002</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fbcec_row6_col0" class="data row6 col0" >0.000063</td>
#       <td id="T_fbcec_row6_col1" class="data row6 col1" >0.000041</td>
#       <td id="T_fbcec_row6_col2" class="data row6 col2" >0.000022</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fbcec_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_fbcec_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_fbcec_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fbcec_row8_col0" class="data row8 col0" >0.000220</td>
#       <td id="T_fbcec_row8_col1" class="data row8 col1" >0.000191</td>
#       <td id="T_fbcec_row8_col2" class="data row8 col2" >0.000029</td>
#     </tr>
#     <tr>
#       <th id="T_fbcec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fbcec_row9_col0" class="data row9 col0" >0.000168</td>
#       <td id="T_fbcec_row9_col1" class="data row9 col1" >0.000089</td>
#       <td id="T_fbcec_row9_col2" class="data row9 col2" >0.000079</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Checking ANN MODEL

# %%
#Importing libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import r2_score
import random

# %%
#Training FNN with Adam optimizer
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)
model = Sequential()
model.add(Dense(units=64, activation='relu', input_shape=(X_train_sc.shape[1],)))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=1))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
history = model.fit(X_train_sc, y_train, validation_data=(X_test_sc, y_test),
                   epochs=1000, batch_size=32, verbose=1)
y_pred = model.predict(X_test_sc)
print(r2_score(y_test, y_pred))
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - loss: 1.1601 - val_loss: 0.9829
# Epoch 2/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9039 - val_loss: 0.9088
# Epoch 3/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8394 - val_loss: 0.8680
# Epoch 4/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8077 - val_loss: 0.8426
# Epoch 5/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7862 - val_loss: 0.8208
# Epoch 6/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7690 - val_loss: 0.7989
# Epoch 7/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7515 - val_loss: 0.7794
# Epoch 8/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7337 - val_loss: 0.7544
# Epoch 9/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7127 - val_loss: 0.7295
# Epoch 10/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6906 - val_loss: 0.7038
# Epoch 11/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6698 - val_loss: 0.6819
# Epoch 12/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6482 - val_loss: 0.6596
# Epoch 13/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6219 - val_loss: 0.6343
# Epoch 14/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5967 - val_loss: 0.6133
# Epoch 15/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5695 - val_loss: 0.5912
# Epoch 16/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5435 - val_loss: 0.5713
# Epoch 17/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0739 - val_loss: 0.2223
# Epoch 467/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0734 - val_loss: 0.2303
# Epoch 468/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0730 - val_loss: 0.2359
# Epoch 469/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0726 - val_loss: 0.2318
# Epoch 470/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0730 - val_loss: 0.2284
# Epoch 471/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0726 - val_loss: 0.2318
# Epoch 472/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0716 - val_loss: 0.2314
# Epoch 473/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0726 - val_loss: 0.2363
# Epoch 474/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0731 - val_loss: 0.2333
# Epoch 475/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0720 - val_loss: 0.2285
# Epoch 476/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0736 - val_loss: 0.2350
# Epoch 477/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0718 - val_loss: 0.2345
# Epoch 478/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0713 - val_loss: 0.2273
# Epoch 479/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0722 - val_loss: 0.2259
# Epoch 480/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0717 - val_loss: 0.2401
# Epoch 481/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0713 - val_loss: 0.2184
# Epoch 482/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0715 - val_loss: 0.2355
# Epoch 483/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0714 - val_loss: 0.2289
# Epoch 484/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0706 - val_loss: 0.2312
# Epoch 485/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0723 - val_loss: 0.2259
# Epoch 486/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0715 - val_loss: 0.2286
# Epoch 487/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0709 - val_loss: 0.2285
# Epoch 488/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0711 - val_loss: 0.2274
# Epoch 489/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0714 - val_loss: 0.2264
# Epoch 490/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0722 - val_loss: 0.2247
# Epoch 491/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0707 - val_loss: 0.2301
# Epoch 492/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0704 - val_loss: 0.2233
# Epoch 493/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0714 - val_loss: 0.2282
# Epoch 494/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0708 - val_loss: 0.2324
# Epoch 495/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0709 - val_loss: 0.2283
# Epoch 496/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0703 - val_loss: 0.2262
# Epoch 497/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0716 - val_loss: 0.2351
# Epoch 498/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0715 - val_loss: 0.2311
# Epoch 499/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0712 - val_loss: 0.2286
# Epoch 500/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0704 - val_loss: 0.2320
# Epoch 501/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0693 - val_loss: 0.2278
# Epoch 502/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0705 - val_loss: 0.2379
# Epoch 503/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0718 - val_loss: 0.2286
# Epoch 504/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0696 - val_loss: 0.2320
# Epoch 505/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0701 - val_loss: 0.2312
# Epoch 506/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0700 - val_loss: 0.2346
# Epoch 507/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0701 - val_loss: 0.2362
# Epoch 508/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0691 - val_loss: 0.2417
# Epoch 509/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0724 - val_loss: 0.2274
# Epoch 510/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0706 - val_loss: 0.2377
# Epoch 511/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0706 - val_loss: 0.2348
# Epoch 512/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0698 - val_loss: 0.2292
# Epoch 513/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0700 - val_loss: 0.2400
# Epoch 514/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0706 - val_loss: 0.2393
# Epoch 515/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0713 - val_loss: 0.2360
# Epoch 516/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0699 - val_loss: 0.2373
# Epoch 517/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0702 - val_loss: 0.2508
# Epoch 518/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0714 - val_loss: 0.2444
# Epoch 519/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0711 - val_loss: 0.2387
# Epoch 520/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0693 - val_loss: 0.2342
# Epoch 521/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0716 - val_loss: 0.2426
# Epoch 522/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0707 - val_loss: 0.2444
# Epoch 523/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0712 - val_loss: 0.2410
# Epoch 524/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0717 - val_loss: 0.2420
# Epoch 525/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0714 - val_loss: 0.2434
# Epoch 526/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0699 - val_loss: 0.2283
# Epoch 527/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0715 - val_loss: 0.2397
# Epoch 528/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0717 - val_loss: 0.2362
# Epoch 529/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0727 - val_loss: 0.2545
# Epoch 530/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0715 - val_loss: 0.2395
# Epoch 531/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0707 - val_loss: 0.2403
# Epoch 532/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0728 - val_loss: 0.2461
# Epoch 533/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0732 - val_loss: 0.2275
# Epoch 534/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0721 - val_loss: 0.2398
# Epoch 535/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0728 - val_loss: 0.2396
# Epoch 536/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0743 - val_loss: 0.2478
# Epoch 537/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0731 - val_loss: 0.2433
# Epoch 538/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0742 - val_loss: 0.2479
# Epoch 539/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0742 - val_loss: 0.2346
# Epoch 540/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0743 - val_loss: 0.2332
# Epoch 541/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0742 - val_loss: 0.2459
# Epoch 542/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0769 - val_loss: 0.2450
# Epoch 543/1000
# ...
# Epoch 820/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - val_loss: 0.2115
# Epoch 821/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0520 - val_loss: 0.2071
# Epoch 822/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0513 - val_loss: 0.2165
# Epoch 823/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0531 - val_loss: 0.2086
# Epoch 824/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0524 - val_loss: 0.2137
# Epoch 825/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0530 - val_loss: 0.2141
# Epoch 826/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0550 - val_loss: 0.2098
# Epoch 827/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0539 - val_loss: 0.2134
# Epoch 828/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0539 - val_loss: 0.2027
# Epoch 829/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0509 - val_loss: 0.2005
# Epoch 830/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0510 - val_loss: 0.2010
# Epoch 831/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0507 - val_loss: 0.2040
# Epoch 832/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - val_loss: 0.2008
# Epoch 833/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - val_loss: 0.2000
# Epoch 834/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0477 - val_loss: 0.2012
# Epoch 835/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0463 - val_loss: 0.2000
# Epoch 836/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0460 - val_loss: 0.1960
# Epoch 837/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0439 - val_loss: 0.1966
# Epoch 838/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0441 - val_loss: 0.1970
# Epoch 839/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0425 - val_loss: 0.1986
# Epoch 840/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0429 - val_loss: 0.1988
# Epoch 841/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0411 - val_loss: 0.1960
# Epoch 842/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0412 - val_loss: 0.1973
# Epoch 843/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0415 - val_loss: 0.1960
# Epoch 844/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0409 - val_loss: 0.1942
# Epoch 845/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0408 - val_loss: 0.1923
# Epoch 846/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - val_loss: 0.1962
# Epoch 847/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0398 - val_loss: 0.1928
# Epoch 848/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0400 - val_loss: 0.1915
# Epoch 849/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.1937
# Epoch 850/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397 - val_loss: 0.1926
# Epoch 851/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0403 - val_loss: 0.1926
# Epoch 852/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0402 - val_loss: 0.1927
# Epoch 853/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0476 - val_loss: 0.1982
# Epoch 854/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0571 - val_loss: 0.2010
# Epoch 855/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - val_loss: 0.1939
# Epoch 856/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0427 - val_loss: 0.1938
# Epoch 857/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0408 - val_loss: 0.1957
# Epoch 858/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397 - val_loss: 0.1951
# Epoch 859/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389 - val_loss: 0.1966
# Epoch 860/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0380 - val_loss: 0.1976
# Epoch 861/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0379 - val_loss: 0.1942
# Epoch 862/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0378 - val_loss: 0.1928
# Epoch 863/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.1935
# Epoch 864/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0385 - val_loss: 0.1965
# Epoch 865/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0368 - val_loss: 0.1967
# Epoch 866/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0377 - val_loss: 0.1998
# Epoch 867/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0377 - val_loss: 0.1932
# Epoch 868/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0372 - val_loss: 0.1995
# Epoch 869/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0368 - val_loss: 0.1928
# Epoch 870/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0370 - val_loss: 0.1931
# Epoch 871/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0367 - val_loss: 0.1916
# Epoch 872/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0371 - val_loss: 0.1978
# Epoch 873/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0365 - val_loss: 0.1980
# Epoch 874/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0378 - val_loss: 0.1887
# Epoch 875/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0375 - val_loss: 0.1900
# Epoch 876/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0359 - val_loss: 0.2008
# Epoch 877/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0369 - val_loss: 0.1928
# Epoch 878/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0371 - val_loss: 0.1931
# Epoch 879/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0367 - val_loss: 0.1924
# Epoch 880/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0364 - val_loss: 0.1929
# Epoch 881/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0365 - val_loss: 0.1908
# Epoch 882/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0362 - val_loss: 0.1969
# Epoch 883/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0366 - val_loss: 0.1913
# Epoch 884/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0362 - val_loss: 0.1990
# Epoch 885/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0367 - val_loss: 0.1930
# Epoch 886/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0362 - val_loss: 0.1996
# Epoch 887/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0368 - val_loss: 0.2003
# Epoch 888/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0371 - val_loss: 0.1915
# Epoch 889/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0367 - val_loss: 0.1990
# Epoch 890/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0364 - val_loss: 0.1925
# Epoch 891/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0361 - val_loss: 0.1975
# Epoch 892/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0365 - val_loss: 0.1992
# Epoch 893/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0373 - val_loss: 0.1919
# Epoch 894/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0366 - val_loss: 0.1921
# Epoch 895/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0350 - val_loss: 0.2061
# Epoch 896/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0363 - val_loss: 0.1950
# Epoch 897/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0366 - val_loss: 0.1956
# Epoch 898/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0355 - val_loss: 0.2008
# Epoch 899/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0368 - val_loss: 0.1876
# Epoch 900/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0363 - val_loss: 0.1932
# Epoch 901/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0359 - val_loss: 0.1907
# Epoch 902/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0354 - val_loss: 0.1937
# Epoch 903/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0360 - val_loss: 0.1967
# Epoch 904/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0355 - val_loss: 0.1941
# Epoch 905/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0355 - val_loss: 0.2012
# Epoch 906/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0362 - val_loss: 0.1935
# Epoch 907/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0360 - val_loss: 0.1995
# Epoch 908/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0360 - val_loss: 0.1920
# Epoch 909/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0355 - val_loss: 0.1996
# Epoch 910/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0361 - val_loss: 0.1921
# Epoch 911/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0351 - val_loss: 0.1987
# Epoch 912/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0361 - val_loss: 0.1965
# Epoch 913/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0372 - val_loss: 0.1905
# Epoch 914/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0359 - val_loss: 0.1960
# Epoch 915/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0371 - val_loss: 0.1966
# Epoch 916/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0455 - val_loss: 0.2096
# Epoch 917/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0668 - val_loss: 0.1952
# Epoch 918/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0576 - val_loss: 0.2096
# Epoch 919/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0417 - val_loss: 0.1934
# Epoch 920/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0382 - val_loss: 0.1955
# Epoch 921/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0350 - val_loss: 0.1921
# Epoch 922/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0359 - val_loss: 0.1886
# Epoch 923/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0364 - val_loss: 0.1885
# Epoch 924/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0357 - val_loss: 0.1939
# Epoch 925/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0346 - val_loss: 0.1995
# Epoch 926/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0356 - val_loss: 0.2054
# Epoch 927/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0375 - val_loss: 0.1983
# Epoch 928/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0368 - val_loss: 0.1939
# Epoch 929/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0354 - val_loss: 0.1986
# Epoch 930/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0364 - val_loss: 0.1899
# Epoch 931/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0368 - val_loss: 0.1925
# Epoch 932/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0354 - val_loss: 0.1899
# Epoch 933/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0357 - val_loss: 0.1931
# Epoch 934/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0363 - val_loss: 0.1908
# Epoch 935/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0360 - val_loss: 0.1935
# Epoch 936/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0369 - val_loss: 0.1912
# Epoch 937/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0366 - val_loss: 0.1947
# Epoch 938/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0378 - val_loss: 0.1896
# Epoch 939/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0369 - val_loss: 0.1977
# Epoch 940/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0371 - val_loss: 0.1903
# Epoch 941/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0372 - val_loss: 0.1927
# Epoch 942/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0387 - val_loss: 0.1892
# Epoch 943/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.1884
# Epoch 944/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389 - val_loss: 0.1926
# Epoch 945/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0445 - val_loss: 0.1970
# Epoch 946/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0641 - val_loss: 0.1955
# Epoch 947/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0459 - val_loss: 0.1960
# Epoch 948/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0442 - val_loss: 0.1913
# Epoch 949/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0435 - val_loss: 0.1923
# Epoch 950/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0447 - val_loss: 0.1926
# Epoch 951/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0473 - val_loss: 0.1951
# Epoch 952/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0485 - val_loss: 0.1968
# Epoch 953/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0511 - val_loss: 0.1983
# Epoch 954/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0548 - val_loss: 0.1952
# Epoch 955/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0505 - val_loss: 0.1970
# Epoch 956/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0503 - val_loss: 0.1954
# Epoch 957/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0457 - val_loss: 0.1947
# Epoch 958/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - val_loss: 0.1970
# Epoch 959/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0396 - val_loss: 0.1973
# Epoch 960/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0373 - val_loss: 0.1896
# Epoch 961/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0365 - val_loss: 0.1927
# Epoch 962/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0371 - val_loss: 0.1948
# Epoch 963/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0364 - val_loss: 0.1894
# Epoch 964/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0352 - val_loss: 0.1947
# Epoch 965/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0359 - val_loss: 0.1915
# Epoch 966/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0349 - val_loss: 0.1898
# Epoch 967/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0353 - val_loss: 0.1926
# Epoch 968/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0348 - val_loss: 0.1921
# Epoch 969/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0340 - val_loss: 0.1931
# Epoch 970/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0334 - val_loss: 0.1922
# Epoch 971/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0331 - val_loss: 0.1920
# Epoch 972/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0330 - val_loss: 0.1898
# Epoch 973/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0321 - val_loss: 0.1880
# Epoch 974/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0324 - val_loss: 0.1876
# Epoch 975/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0326 - val_loss: 0.1862
# Epoch 976/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0320 - val_loss: 0.1872
# Epoch 977/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0325 - val_loss: 0.1862
# Epoch 978/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0320 - val_loss: 0.1865
# Epoch 979/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0323 - val_loss: 0.1844
# Epoch 980/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0320 - val_loss: 0.1874
# Epoch 981/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0319 - val_loss: 0.1850
# Epoch 982/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0318 - val_loss: 0.1854
# Epoch 983/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0320 - val_loss: 0.1843
# Epoch 984/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0322 - val_loss: 0.1869
# Epoch 985/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0315 - val_loss: 0.1851
# Epoch 986/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0348 - val_loss: 0.1882
# Epoch 987/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0530 - val_loss: 0.2061
# Epoch 988/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0660 - val_loss: 0.1902
# Epoch 989/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0368 - val_loss: 0.1867
# Epoch 990/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0333 - val_loss: 0.1870
# Epoch 991/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0322 - val_loss: 0.1808
# Epoch 992/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0332 - val_loss: 0.1822
# Epoch 993/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0313 - val_loss: 0.1827
# Epoch 994/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0308 - val_loss: 0.1813
# Epoch 995/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0308 - val_loss: 0.1816
# Epoch 996/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0309 - val_loss: 0.1809
# Epoch 997/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0306 - val_loss: 0.1829
# Epoch 998/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0308 - val_loss: 0.1811
# Epoch 999/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0307 - val_loss: 0.1804
# Epoch 1000/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0311 - val_loss: 0.1778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 0.8559331479066066

# %%
y_train_pred = model.predict(X_train_sc)
print(r2_score(y_train, y_train_pred))
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.9635224241275179

# %%
y_pred = model.predict(X_test_sc)
print(r2_score(y_test, y_pred))
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.8559331479066066

# %%
#Visualized Error Minimization Tracking
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('ANN Error Minimization Tracking')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **ANN Performance Display**

# %%
#Plotting Actual Values against Predicted Values
plt.figure(figsize=(12,6))
plt.subplot(121)
sns.scatterplot(x = y_test, y= y_pred.flatten(), alpha = 0.6, label = 'test set predictions')
plt.scatter(x = y_train, y= y_train_pred.flatten(), alpha = 0.6, label='train set predictions')
plt.plot(y_test, y_test, label='best fit')
plt.legend()
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('ANN Performance R_squared=' + str(round(r2_score(y_test, y_pred),3)))

#Plotting Optimizationo Performance
plt.subplot(122)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('ANN Error Minimization Tracking')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
#Display of Actual and Predicted Values distributions
plt.figure(figsize=(10,7))
sns.histplot(y_test, label="Actual Values")
sns.histplot(y_pred.flatten(), alpha=0.6, label="Predicted Values")
plt.legend()
plt.ylabel("count")
plt.xlabel("values")
plt.title("ANN Distribution Plot - Actual Values Vs Predicted Values")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
print("Training error: {}".format(mean_squared_error(y_train, y_train_pred)))
print("Test error: {}".format(mean_squared_error(y_test, y_pred)))
# Out:
# Training error: 0.04798674696352753
# Test error: 0.17783208681788762

# %% [markdown]
# **Nothing Changes!**
#
# While better than SVR AND KNNR, ANN still lags behind the ensemble models. Of course this is a peculiar hiccup with ann in the presence of limited data as the one used in the project.

# %% [markdown]
# ## Model Comparison

# %%
# R-squared for all models
from sklearn.metrics import r2_score
r_square = {'model': ['Decision Tree Regressor (DTR)', 'RandomForest Regressor (RFR)', 'Gradient Boosting Regressor (GBR)', 
                         'Support Vector Regressor (SVR)', 'K-Nearest Neighbor Regressor (KNNR)', 'Artificial Neural Network (ANN)'],
               'R2_score (training)': [dtr.score(X_train_sc, y_train), rfr.score(X_train_sc, y_train), gbr.score(X_train_sc, y_train), 
                                       svr.score(X_train_sc, y_train), knnr.score(X_train_sc, y_train), r2_score(y_train, y_train_pred)],
              'R2_score (test)': [dtr.score(X_test_sc, y_test), rfr.score(X_test_sc, y_test), gbr.score(X_test_sc, y_test), 
                                  svr.score(X_test_sc, y_test), knnr.score(X_test_sc, y_test), r2_score(y_test, y_pred)]}
r_square = pd.DataFrame(r_square)
r_square
# Out:
#                                  model  R2_score (training)  R2_score (test)
# 0        Decision Tree Regressor (DTR)             1.000000         0.924121
# 1         RandomForest Regressor (RFR)             0.985677         0.960674
# 2    Gradient Boosting Regressor (GBR)             0.999996         0.970828
# 3       Support Vector Regressor (SVR)             0.809765         0.682835
# 4  K-Nearest Neighbor Regressor (KNNR)             1.000000         0.595443
# 5      Artificial Neural Network (ANN)             0.963522         0.855933

# %%
#Abbreviating model names
r_square['model'] = ['DTR', 'RFR', 'GBR', 'SVR', 'KNNR', 'ANN']

#ordering test score
r_square1 = r_square.sort_values('R2_score (test)')
r_square1
# Out:
#   model  R2_score (training)  R2_score (test)
# 4  KNNR             1.000000         0.595443
# 3   SVR             0.809765         0.682835
# 5   ANN             0.963522         0.855933
# 0   DTR             1.000000         0.924121
# 1   RFR             0.985677         0.960674
# 2   GBR             0.999996         0.970828

# %%
plt.bar(r_square1['model'], r_square1['R2_score (training)'], label='train score', color='darkorange')
plt.bar(r_square1['model'], r_square1['R2_score (test)'], label='test score', color='steelblue')
plt.ylabel('R2_score')
plt.legend(loc='best')
plt.ylim()
plt.show()

# %%
# MSE for all models
error = {'model': ['Decision Tree Regressor (DTR)', 'RandomForest Regressor (RFR)', 'Gradient Boosting Regressor (GBR)', 
                         'Support Vector Regressor (SVR)', 'K-Nearest Neighbor Regressor (KNNR)', 'Artificial Neural Network (ANN)'],
               'MSE train': [round(mse(y_train, dtr.predict(X_train_sc)),3), round(mse(y_train, rfr.predict(X_train_sc)),3), 
                       round(mse(y_train, gbr.predict(X_train_sc)),3), round(mse(y_train, svr.predict(X_train_sc)),3),
                       round(mse(y_train, knnr.predict(X_train_sc)),3), round(mse(y_train, y_train_pred),3)],
        'MSE test': [round(mse(y_test, dtr.predict(X_test_sc)),3), round(mse(y_test, rfr.predict(X_test_sc)),3), 
                       round(mse(y_test, gbr.predict(X_test_sc)),3), round(mse(y_test, svr.predict(X_test_sc)),3),
                       round(mse(y_test, knnr.predict(X_test_sc)),3), round(mse(y_test, y_pred),3)]}
error = pd.DataFrame(error)
error
# Out:
#                                  model  MSE train  MSE test
# 0        Decision Tree Regressor (DTR)      0.000     0.094
# 1         RandomForest Regressor (RFR)      0.019     0.049
# 2    Gradient Boosting Regressor (GBR)      0.000     0.036
# 3       Support Vector Regressor (SVR)      0.250     0.391
# 4  K-Nearest Neighbor Regressor (KNNR)      0.000     0.499
# 5      Artificial Neural Network (ANN)      0.048     0.178

# %%
#Error with model names abbreviated
error['model'] = ['DTR', 'RFR', 'GBR', 'SVR', 'KNNR', 'ANN']

#ordering by test error
error1 = error.sort_values('MSE test')
error1
# Out:
#   model  MSE train  MSE test
# 2   GBR      0.000     0.036
# 1   RFR      0.019     0.049
# 0   DTR      0.000     0.094
# 5   ANN      0.048     0.178
# 3   SVR      0.250     0.391
# 4  KNNR      0.000     0.499

# %%
plt.bar(error1['model'], error1['MSE test'], label='test error', color='darkorange')
plt.bar(error1['model'], error1['MSE train'], label='train error', color='steelblue')
plt.ylabel('MeanSquaredError')
plt.legend(loc='best')
plt.show()

# %%
#Viewing score and error side by side
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.bar(r_square1['model'], r_square1['R2_score (training)'], label='train score', color='darkorange')
plt.bar(r_square1['model'], r_square1['R2_score (test)'], label='test score', color='steelblue')
plt.ylabel('R2_score')
plt.legend(loc='best')
plt.ylim()
plt.subplot(122)
plt.bar(error1['model'], error1['MSE test'], label='test error', color='steelblue')
plt.bar(error1['model'], error1['MSE train'], label='train error', color='darkorange')
plt.ylabel('MeanSquaredError')
plt.legend(loc='best')
plt.show()
